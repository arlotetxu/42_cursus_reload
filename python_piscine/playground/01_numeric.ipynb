# %% [markdown]
# # NUMERIC

# %%
num = 3
print(f"{type(num)}")
# Out:
# <class 'int'>

# %%
float_n = 3.14
print(f"{type(float_n)}")
# Out:
# <class 'float'>

# %%
complex_n = 2+1j
print(f"{type(complex_n)}")
# Out:
# <class 'complex'>

# %%
n = int('101', base=10) # Al castear con int(), se puede especificar la base. En este caso, base decimal (base=10)
print(n)
# Out:
# 101

# %%
n = int('101', base=2) # En este caso, base binaria (base=2)
print(n)
# Out:
# 5

# %%
a = 5
b = 2
a ** b
# Out:
# 25
