# %% [markdown]
# # TUPLAS

# %% [markdown]
# Secuencia de valores separados por comas. Mejor definirlos entre parentesis aunque esto no define la tupla. Sus elementos son *__inmutables__*, es decir, no se pueden añadir o eliminar elementos a una tupla.

# %% [markdown]
# ### METODOS ###

# %%
my_tuple = (1, 2, 3)
[x for x in dir(my_tuple) if not x.startswith("__")]
# Out:
# ['count', 'index']

# %%
type(my_tuple)
# Out:
# tuple

# %% [markdown]
# Casteando un lista a una tupla:

# %%
my_tuple = tuple([1, 2, 3, 4, 4])
type(my_tuple)
# Out:
# tuple

# %% [markdown]
# ##### __.count(x)__
# (Cuenta el numero de elementos x que se encuentran en la tupla)

# %%
my_tuple.count(4)
# Out:
# 2

# %% [markdown]
# ##### __.index(x)__
# (Devuelve el indice del primer valor encontrado *x*)

# %%
my_tuple
my_tuple.index(4)
# Out:
# 3

# %% [markdown]
# ##### __len()__
# (Devuelve el numero de elementos que componen la tupla)

# %%
len(my_tuple)
# Out:
# 5

# %% [markdown]
# ##### Intentando modificar una tupla

# %%
my_tuple[0] = 8 # Provocando el error
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 my_tuple[0] = 8 # Provocando el error
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# ##### Concatenando tuplas
# (Se pueden "añadir" elementos a una tupla, pero lo que realmente sucede es que se está creando una nueva. Esto lo podemos ver con la funcion built-in id, que seria similar a mostrar la dirección de memoria)

# %%
id(my_tuple)
# Out:
# 4450330976

# %%
my_tuple += (6, 7)
id(my_tuple)
# Out:
# 4455163376

# %% [markdown]
# ##### Crear tupla con un solo elemento

# %%
my_new_tuple = 2,
type(my_new_tuple)
# Out:
# tuple
