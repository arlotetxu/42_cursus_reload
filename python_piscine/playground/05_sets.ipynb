# %% [markdown]
# # SETS

# %% [markdown]
# Colección desordenada de DISTINTOS objetos. Debido a que los elementos se encuentran desordenados, no tienen un registro por indices. Hay 2 tipo se sets:
# - set --> mutable
# - frozenset --> inmutable

# %% [markdown]
# #### CREACION
# (se crean como una serie de objetos separados por comas y dentro de llaves (curly brackets)

# %%
my_set = {"a", "b", "c", "c"}
print(my_set) # Observa que se eliminan los elementos repetidos y estan desordenados
# Out:
# {'c', 'a', 'b'}

# %%
my_list = [1, 2, 22, 2]
my_set = set(my_list)
print(my_set)
# Out:
# {1, 2, 22}

# %% [markdown]
# ### ACCEDIENDO A SUS MIEMBROS

# %% [markdown]
# Un set no permite usar slicing ([:2]). Para acceder a sus miembros, hay que iterar sobre los mismos con un loop

# %%
my_set[0] # Provocando el error
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1771029/4162686877.py in <module>
# ----> 1 my_set[0] # Provocando el error
#
# TypeError: 'set' object is not subscriptable

# %%
my_set[:1] # Provocando el error
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 my_set[:1]
#
# TypeError: 'set' object is not subscriptable

# %%
for item in my_set:
    print(item)
# Out:
# 1
# 2
# 22

# %% [markdown]
# ### METODOS

# %%
[x for x in dir(my_set) if not x.startswith("__")]
# Out:
# ['add',
#  'clear',
#  'copy',
#  'difference',
#  'difference_update',
#  'discard',
#  'intersection',
#  'intersection_update',
#  'isdisjoint',
#  'issubset',
#  'issuperset',
#  'pop',
#  'remove',
#  'symmetric_difference',
#  'symmetric_difference_update',
#  'union',
#  'update']

# %% [markdown]
# ##### __.add()__
# (Añade un item a un set)

# %%
my_set.add(33)
print(my_set)
# Out:
# {1, 2, 22, 33}

# %% [markdown]
# ##### __.update()__
# (Añade multiples items a un set. Es necesario pasar un iterable)

# %%
my_set.update((44, 55))
print(my_set)
# Out:
# {1, 2, 33, 44, 22, 55}

# %% [markdown]
# ##### __.remove__
# (Elimina un item especifico de un set)

# %%
my_set.remove(55)
print(my_set)
# Out:
# {1, 2, 33, 44, 22}

# %%
my_set.remove(888) # Provocando el error al no tener el item 888 en el set
print(my_set)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 my_set.remove(888) # Provocando el error al no tener el item 888 en el set
#       2 print(my_set)
#
# KeyError: 888

# %% [markdown]
# ##### __.discard()__
# (Funciona de una manera similar a .remove pero no muestra error en caso de que el item especificado no se encuentre en el set)

# %%
my_set.discard(888)
print(my_set)
# Out:
# {1, 2, 33, 44, 22}

# %% [markdown]
# ##### __.pop()___
# (Elimina y retorna un item *ARBITRARIO* de un set)

# %%
print(f"{my_set.pop()}")
print(my_set)
# Out:
# 1
# {2, 33, 44, 22}

# %% [markdown]
# ##### __.clear()__
# (Vacia un set)

# %%
print(my_set)
my_set.clear()
print(my_set)
# Out:
# {2, 33, 44, 22}
# set()

# %% [markdown]
# ##### __del__
# (Elimina un set)

# %%
del(my_set)
print(my_set) # Provocando el error
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 2
#       1 del(my_set)
# ----> 2 print(my_set)
#
# NameError: name 'my_set' is not defined

# %% [markdown]
# ##### __.union()__
# (Combina 2 sets y retornando la combinación en un nuevo set)

# %%
my_set1 = {"a", "b", "c", "d"}
my_set2 = {"z", "x", "y"}
my_set3 = my_set1.union(my_set2)
print(my_set3)
# Out:
# {'b', 'c', 'd', 'z', 'y', 'x', 'a'}

# %% [markdown]
# ##### __.intersection()__
# (Retorna un nuevo set con los elementos comunes de 2 sets)

# %%
my_set1 = {"a", "b", "c", "d"}
my_set2 = {"z", "a", "y"}
my_set3 = my_set1.intersection(my_set2)
print(my_set3)
# Out:
# {'a'}

# %% [markdown]
# ##### __.difference()__
# (Retorna un nuevo set con los elementos diferentes de 2 sets)

# %%
my_set1 = {"a", "b", "c", "d"}
my_set2 = {"z", "a", "y"}
my_set3 = my_set1.difference(my_set2)
print(my_set3)
# Out:
# {'d', 'b', 'c'}

# %% [markdown]
# Para eliminar duplicados en una lista...

# %%
my_list = [1, 2, 3, 4, 2, 4]
my_set = set(my_list)
print(my_set)
my_list = list(my_set)
print(my_list)
# Out:
# {1, 2, 3, 4}
# [1, 2, 3, 4]
